# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location.
#
# You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
#
# This task will be done in following steps:
#
# 1. First get the webpage https://www.naukri.com/
#
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
#
# 3. Then click the search button.
#
# 4. Then scrape the data for the first 10 jobs results you get.
#
# 5. Finally create a dataframe of the scraped data.
#
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
#let's first conect to the driver
driver=webdriver.Chrome(r"C:\Users\kundan.kaushik\Downloads\chrome_driver\chromedriver.exe")

# %%
#open the page on automated chrome browser

#step 1- First get the webpage https://www.naukri.com/
driver.get('https://www.naukri.com/')

# %%
#step 2- Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.

#entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
#entering Company as required in the question

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
# step 3- Then click the search button.

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# step 4- Then scrape the data for the first 10 jobs results you get.

job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scaping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    

#scraping company name from the given page
comany_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in comany_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
# Finally create a dataframe of the scraped data.

#creating the dataframe from above data-

df=pd.DataFrame({'Job Title:':job_title,'Job Location':job_location,'Company Name':company_name,'Experienced Required':experience_required})
df
# Out:
#                                           Job Title:  \
# 0  Contractual Hiring For Top MNC || Business Dat...
# 1                                Senior Data Analyst
# 2                        Data Analyst - CRM Platform
# 3                        HCL hiring For Data Analyst
# 4                              Customer Data Analyst
# 5                                   Sr. Data Analyst
# 6                             Data Analyst - FinTech
# 7  Assistant Manager/Manager - Data Analyst - Ana...
# 8                          Python Data Analyst - WFH
# 9                    Data Analyst - Decision Science
#
#                                         Job Location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 3                 Bangalore/Bengaluru, Pune, Chennai
# 4                                Bangalore/Bengaluru
# 5                          Bangalore/Bengaluru, Pune
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location.
#
# You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
#
# This task will be done in following steps:
#
# 1. First get the webpage https://www.naukri.com/
#
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
#
# 3. Then click the search button.
#
# 4. Then scrape the data for the first 10 jobs results you get.
#
# 5. Finally create a dataframe of the scraped data.
#
# Note: All of the above steps have to be done in code. No step is to be done manually.

# %%
#open the page on automated chrome browser

#step 1- First get the webpage https://www.naukri.com/
driver.get('https://www.naukri.com/')

# %%
#step 2- Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the location” field.

#entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Scientist")

# %%
#entering Company as required in the question

location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location.send_keys("Bangalore")

# %%
# step 3- Then click the search button.

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
# step 4- Then scrape the data for the first 10 jobs results you get.

job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scaping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    

#scraping company name from the given page
comany_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in comany_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
# Finally create a dataframe of the scraped data.

#creating the dataframe from above data-

df=pd.DataFrame({'Job Title:':job_title,'Job Location':job_location,'Company Name':company_name,'Experienced Required':experience_required})
df
# Out:
#                                           Job Title:  \
# 0  Job Opportunity on Data Science_ Python with T...
# 1                   Assistant Manager - Data Science
# 2                   Analystics & Modeling Specialist
# 3  Hiring For DATA Scientist @ NTT DATA Business ...
# 4                       Data Scientist/AIML Engineer
# 5  ACN - Applied Intelligence - C4DI - Sustainabi...
# 6                                  Lead ML Scientist
# 7                      Tcs Hiring For Data Scientist
# 8                                Data Scientist - II
# 9                       Data Scientist - A.P. Maersk
#
#                                         Job Location  \
# 0  Bangalore/Bengaluru, Kolkata, Hyderabad/Secund...
# 1                  Bangalore/Bengaluru, Mumbai, Pune
# 2  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 3  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 4  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %% [markdown]
# You have to use the location and salary filter.
#
# You have to scrape data for “Data Scientist” designation for first 10 job results.
#
# You have to scrape the job-title, job-location, company name, experience required.
#
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
#
# The task will be done as shown in the below steps:

# %% [markdown]
# 1. first get the webpage https://www.naukri.com/
#
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
#
# 3. Then click the search button.
#
# 4. Then apply the location filter and salary filter by checking the respective boxes
#
# 5. Then scrape the data for the first 10 jobs results you get.
#
# 6. Finally create a dataframe of the scraped data.
#
# Note: All of the above steps have to be done in code. No step is to be done manually##

# %%
# step 1 -first get the webpage https://www.naukri.com/

#open the page on automated chrome browser
driver.get('https://www.naukri.com/')

# %%
# step 2 -Enter “Data Scientist” in “Skill, Designations, and Companies” field.

#entering designation as required in the question

designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Scientist")

# %%
# step 3- Then click the search button.

search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
#The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

# step 4 -Then apply the location filter and salary filter by checking the respective boxes

loc_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[5]/div[2]/div[3]/label/i")

loc_filter.click()

# %%
# The salary filter to be used is “3-6” lakhs


salary_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/i")

salary_filter.click()

# %%
# step 5-Then scrape the data for the first 10 jobs results you get.

job_title=[]
job_location=[]
company_name=[]
experience_required=[]

#scaping job title from the given page
title_tags=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)
    
#scraping job location from the given page
location_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)
    

#scraping company name from the given page
comany_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in comany_tags[0:10]:
    company=i.text
    company_name.append(company)
    
#scraping job Experience from the given page
experience_tags=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
# step 6- Finally create a dataframe of the scraped data.

#creating the dataframe from above data-

df=pd.DataFrame({'Job Title:':job_title,'Job Location':job_location,'Company Name':company_name,'Experienced Required':experience_required})
df
# Out:
#                               Job Title:  \
# 0                         Data Scientist
# 1        DigitalBCG GAMMA Data Scientist
# 2                         Data Scientist
# 3    Data Scientist / Chat-bot Developer
# 4                    Lead Data Scientist
# 5  Data Scientist - Predictive Analytics
# 6               Knowledge/Data Scientist
# 7                         Data Scientist
# 8                         Data Scientist
# 9              Data Scientist, Associate
#
#                                         Job Location             Company Name  \
# 0                 Noida, Nagpur, Bangalore/Bengaluru              GlobalLogic
# 1                     New Delhi, Bangalore/Bengaluru  Boston Consulting Group
# 2                                   Gurgaon/Gurugram                    Optum
# 3  New Delhi, Bangalore/Bengaluru, Mumbai (All Ar...             Big Seo Buzz
# 4         Noida(Sector-59 Noida)\n(WFH during Covid)  R Systems International
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#
# 1. Brand
#
# 2. Product Description
#
# 3. Price

# %% [markdown]
#  To scrape the data you have to go through following steps:
#
# 1. Go to Flipkart webpage by url : https://www.flipkart.com/
#
# 2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and
# click the search icon
#
# 3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the
# required data as usual.
#
# 4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then
# click on it.
#
# 5. Now scrape data from this page as usual
#
# 6. Repeat this until you get data for 100 sunglasses

# %%
#let's first conect to the driver
driver=webdriver.Chrome(r"C:\Users\kundan.kaushik\Downloads\chrome_driver\chromedriver.exe")

# %%
# step 1- Go to Flipkart webpage by url : https://www.flipkart.com/
#open the page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# step 2 -Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon

#entering brand in the search field as required in the question

designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys("sunglasses")

# %%
# searching for given brand

search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
start=0
end=3
brands=[]
price=[]
product_descriptions=[]
countBrand=0
countprice=0
countprodDes=0
for page in range(start,end):
    #scraping brand
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in range(0,len(brand_tags)):
        if countBrand<100:
            brands.append(brand_tags[i].text)
            countBrand+=1
            
    #scraping product price 
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in range(0,len(price_tags)):
        if countprice<100:
            price.append(price_tags[i].text)
            countprice+=1
            
    #scraping product description        
    product_description_tags=driver.find_elements(By.CLASS_NAME,"IRpwTa")
    for i in range(0,len(product_description_tags)):
         if countprodDes<100:
            product_descriptions.append(product_description_tags[i].text)
            countprodDes+=1
            
    #for next page
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brands),len(product_descriptions),len(price))
# Out:
# 100 100 100

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Brand:':brands,'Product Description':product_descriptions,'Price':price})
df
# Out:
#             Brand:                                Product Description   Price
# 0   ROZZETTA CRAFT       UV Protection Cat-eye Sunglasses (Free Size)    ₹359
# 1    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)  ₹1,128
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹799
# 3    VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...    ₹901
# 4   ROZZETTA CRAFT  UV Protection Retro Square Sunglasses (Free Size)    ₹449
# ..             ...                                                ...     ...
# 95   VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...  ₹1,049
# 96    CRYSTAL CART  Polarized, UV Protection, Mirrored, Gradient R...    ₹476
# 97        Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹759
# 98              Mi           Polarized Aviator Sunglasses (Free Size)    ₹799
# 99       ROYAL SON  UV Protection, Gradient Butterfly Sunglasses (60)    ₹559
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.

# %% [markdown]
# ## This task will be done in following steps:
#
# 1. First get the webpage https://www.flipkart.com/
#
# 2. Enter “iphone 11” in “Search” field .
#
# 3. Then click the search button.

# %% [markdown]
# scrape the tick marked attributes
#
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.
# Note: All the steps required during scraping should be done through code only and not manually.

# %%
# step 1- First get the webpage https://www.flipkart.com/
#open the page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# step 2 -Enter “iphone 11” in “Search” field .

#entering iphone 11 in the search field as required in the question

designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys("iphone 11")

# %%
# searching for iphone 11

search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
#//a[@class="_1fQZEK"]

#fetch URL for APPLE iPhone 11 (Black, 64 GB)

iphone_urls=[]

url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url[0:4]:
    iphone_urls.append(i.get_attribute('href'))
    
iphone_urls
# Out:
# ['https://www.flipkart.com/apple-iphone-11-white-64-gb/p/itmfc6a7091eb20b?pid=MOBFWQ6BVWVEH3XE&lid=LSTMOBFWQ6BVWVEH3XEMXQMLO&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=6b7d268b-250a-4ac9-af5e-6b3d0e03334c.MOBFWQ6BVWVEH3XE.SEARCH&ppt=hp&ppn=homepage&ssid=ipk2h3e5ao0000001663089944583&qH=f6cdfdaa9f3c23f3',
#  'https://www.flipkart.com/apple-iphone-11-white-128-gb/p/itme32df47ea6742?pid=MOBFWQ6B7KKRXDDS&lid=LSTMOBFWQ6B7KKRXDDSUPVRTR&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=6b7d268b-250a-4ac9-af5e-6b3d0e03334c.MOBFWQ6B7KKRXDDS.SEARCH&ppt=hp&ppn=homepage&ssid=ipk2h3e5ao0000001663089944583&qH=f6cdfdaa9f3c23f3',
# ...

# %%
index = [idx for idx, s in enumerate(iphone_urls) if 'apple-iphone-11-black' in s][0]

print(iphone_urls[index])
# Out:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/p/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART&q=iphone+11&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=6b7d268b-250a-4ac9-af5e-6b3d0e03334c.MOBFWQ6BXGJCEYNY.SEARCH&ppt=hp&ppn=homepage&ssid=ipk2h3e5ao0000001663089944583&qH=f6cdfdaa9f3c23f3

# %%
driver.get(iphone_urls[index])

# %%
all_reviews_button=driver.find_element(By.XPATH,'//div[@class="_3UAT2v _16PBlm"]')
all_reviews_button.click()

# %%
start=0
end=10

review_summarys=[]
full_reviews=[]
ratings=[]

count_rating=0
count_full_review=0
count_summarys=0




for page in range(start,end):
    #scaping Review summary from the given page
    review_summary_tags=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in range(0,len(review_summary_tags)):
        if count_summarys<100:
            review_summarys.append(review_summary_tags[i].text)
            count_summarys+=1
    
    
    #scaping rating from the given page
    rating_tags=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in range(0,len(rating_tags)):
        if count_rating<100:
            ratings.append(rating_tags[i].text)
            count_rating+=1
            
    #scaping rating from the given page
    full_review_tags=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in range(0,len(full_review_tags)):
        if count_full_review<100:
            full_reviews.append(full_review_tags[i].text)
            count_full_review+=1
            
    #for next page
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]/span')
    next_button.click()
    time.sleep(5)

# %%
print(len(ratings),len(review_summarys),len(full_reviews))
# Out:
# 100 100 100

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Rating:':ratings,'Review summary':review_summarys,'Full review':full_reviews})
df
# Out:
#    Rating:       Review summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        5   Highly recommended
# 4        5    Worth every penny
# ..     ...                  ...
# 95       5    Worth every penny
# 96       5   Highly recommended
# 97       5     Perfect product!
# 98       5             Terrific
# 99       5            Wonderful
#
#                                           Full review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   What a camera .....just awesome ..you can feel...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  Smooth like butter, camera like fantabulous, s...
# 96  Amazing camera quality as expected, battery al...
# 97  Iphone is just awesome.. battery backup is ver...
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
#
# You have to scrape 4 attributes of each sneaker:
#
# 1. Brand
#
# 2. Product Description
#
# 3. Price

# %%
# step 1- First get the webpage https://www.flipkart.com/
#open the page on automated chrome browser
driver.get('https://www.flipkart.com/')

# %%
# step 2 -Enter “sneakers” in “Search” field .

#entering sneakers in the search field as required in the question

designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys("sneakers")

# %%
# searching for sneakers

search=driver.find_element(By.CLASS_NAME,"_34RNph")
search.click()

# %%
start=0
end=3

brands=[]
brand_count=0
product_desc=[]
product_count=0
prices=[]
prices_count=0




for page in range(start,end):
    #scaping brand from the given page
    brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in range(0,len(brand_tags)):
        if brand_count<100:
            brands.append(brand_tags[i].text)
            brand_count+=1
    
    
    #scaping product desription from the given page
    product_desc_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in range(0,len(product_desc_tags)):
        if product_count<100:
            product_desc.append(product_desc_tags[i].text)
            product_count+=1
            
    #scaping rating from the given page
    prices_desc_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in range(0,len(prices_desc_tags)):
        if prices_count<100:
            prices.append(prices_desc_tags[i].text)
            prices_count+=1
            
    #for next page
    next_button=driver.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(5)

# %%
print(len(prices))
print(len(product_desc))
print(len(brands))
# Out:
# 100
# 100
# 100

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Brand':brands,'Product Description':product_desc,'Price':prices})
df
# Out:
#            Brand                                Product Description Price
# 0         Layasa                                 Sneakers For Women  ₹579
# 1       sixXplus  casaul for men(blue) sneaker for men Sneakers ...  ₹524
# 2             TR                                   Sneakers For Men  ₹295
# 3         Shozie  Breathable, Walking, Running, Casual, Gym Shoe...  ₹379
# 4         Layasa                              supr Sneakers For Men  ₹199
# ..           ...                                                ...   ...
# 95        RONSON                                   Sneakers For Men  ₹599
# 96     Deals4you                                   Sneakers For Men  ₹299
# 97        Layasa  Flash White Sneakers For Men White Shoes Casua...  ₹399
# 98  Robbie jones                                   Sneakers For Men  ₹394
# 99         BIRDE                                   Sneakers For Men  ₹504
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q7: Go to the link - https://www.myntra.com/shoes
#
# Set second Price filter and Color filter to “Black”, as shown in the below image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Note: Applying the filter and scraping the data, everything should be done through code only and there should not be any manual step.

# %%
# step 1- First get the webpage - https://www.myntra.com/shoes
#open the page on automated chrome browser
driver.get('https://www.myntra.com/shoes')

# %%
# Set second Price filter on page

price_filter=driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")

price_filter.click()

# %%
# Set color filter on page

color_filter=driver.find_element(By.XPATH,"/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")

color_filter.click()

# %%
#scraping product info

start=0
end=2
product_info=[]
product_info_count=0

shoe_price=[]
shoe_price_count=0

for page in range(start,end):
    
    product_desc_tags=driver.find_elements(By.XPATH,'//div[@class="product-productMetaInfo"]')
    for i in range(0,len(product_desc_tags)):
        if product_info_count<100:
            product_info.append(product_desc_tags[i].text)
            product_info_count+=1
            
    
    shoe_price__desc_tags=driver.find_elements(By.XPATH,'//div[@class="product-price"]')
    for i in range(0,len(shoe_price__desc_tags)):
        if shoe_price_count<100:
            shoe_price.append(shoe_price__desc_tags[i].text)
            shoe_price_count+=1
    
    
    next_button=driver.find_element(By.XPATH,'//li[@class="pagination-next"]')
    next_button.click()
    time.sleep(3)

print(len(shoe_price))
print(len(product_info))
# Out:
# 100
# 100

# %%
print(len(shoe_price))
#for p in product_info:
    #shoe_brand,prod_des,shoe_price=p.splitlines()
    #print(p.splitlines()[0])
    #print(p.splitlines()[1])
    #print(p.splitlines()[2])
# Out:
# 100

# %%
#arranging data
print(len(product_info))


actual_prices=[]
discounted_prices=[]

shoes_infos=[]
i=0

for p in product_info:
    shoe_brand=p.splitlines()[0]
    prod_des=p.splitlines()[1]
    shoe_p=shoe_price[i]
    i+=1
    #discounted_price=shoe_price[0:shoe_price.rfind('Rs.')]
    #actual_price=shoe_price[shoe_price.rfind('Rs.'):]
    shoes_info={"Brand": shoe_brand,"Short Shoe description": prod_des,"Price of the shoe": shoe_p}
    shoes_infos.append(shoes_info)
# Out:
# 100

# %%
df = pd.DataFrame(shoes_infos)
df
# Out:
#                Brand          Short Shoe description  \
# 0               Nike  Men ZOOM WINFLO8 Running Shoes
# 1   ADIDAS Originals   Men Leather Niteball Sneakers
# 2               Nike    Men React Infinity 3 Running
# 3   ADIDAS Originals        Men Niteball II Sneakers
# 4           Skechers                Men Sports Shoes
# ..               ...                             ...
# 95    Tommy Hilfiger   Women Solid Slim Heel Sandals
# 96    Tommy Hilfiger    Women Leather Kitten Sandals
# 97    Tommy Hilfiger          Women Leather Sneakers
# 98          Columbia   Women REDMOND V2 TrekkingShoe
# 99            ADIDAS     Women Solar Glide 5 Running
#
#               Price of the shoe
# 0      Rs. 7880Rs. 8295(5% OFF)
# 1   Rs. 10799Rs. 11999(10% OFF)
# 2    Rs. 13295Rs. 13995(5% OFF)
# 3    Rs. 9349Rs. 10999(15% OFF)
# 4                      Rs. 8499
# ..                          ...
# 95                     Rs. 7299
# 96    Rs. 7199Rs. 7999(10% OFF)
# ...

# %% [markdown]
# ### Q8: Go to webpage https://www.amazon.in/
#
# Enter “Laptop” in the search field and then click the search icon.
#
#
# Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## After setting the filters scrape first 10 laptops data. You have to scrape 3 attributesfor each laptop:
#
# 1. Title
# 2. Ratings
# 3. Price

# %%
# step 1- First get the webpage - https://www.amazon.in/
#open the page on automated chrome browser
driver.get('https://www.amazon.in/')

# %%
#entering Laptop as required in the question

product_search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
product_search.send_keys("Laptop")

# %%
#searching value
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()

# %%
# Then set CPU Type filter to “Intel Core i7”

cpu_filter=driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[5]/li[10]/span/a/div/label/i")

cpu_filter.click()

# %%
titles=[]
ratings=[]
l_prices=[]

title_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title_tags[0:10]:
    title=i.text
    titles.append(title)
    
rating_tags=driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]')
for i in rating_tags[0:10]:
    r=i.text
    ratings.append(r)
    
laptop_price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in laptop_price_tags[0:10]:
    lprice=i.text
    l_prices.append(lprice)


print(titles) 
print(ratings) 
print(l_prices)
# Out:
# ['Lenovo ThinkBook 15 Intel 11th Gen Core i7 15.6"(39.62 cm)FHD Thin and Light Laptop (16GB/512GB SSD/Windows 11 Home/MS Office H&S 2021/Iris® Xe Graphics/Backlit/Mineral Grey/1.7 Kg) 20VE00W4IH', 'Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen 15.6"(39.62cm) FHD IPS Gaming Laptop (8GB/512GB SSD/4GB NVIDIA GTX 1650/120Hz/Windows 11/Backlit Keyboard/3months Game Pass/Onyx Black/2.2Kg), 81Y401BHIN', 'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN', 'ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms) WQHD 165Hz/3ms, Intel Core i7-12650H 12th Gen, RTX 3070 8GB Graphics, Gaming Laptop (16GB/1TB SSD/Windows 11/Office 2021/Black/2 kg), FX517ZR-HQ030WS', '(Renewed) Lenovo Intel Core i7 5600U 12.5-Inch (31.75 cms) HD (1366 X 768) Laptop (8 GB/256 GB SSD/Windows 10/Intel HD 5500//1.53 Kg), Lenovo X250', 'HP Pavilion x360 11th Gen Intel Core i7 14 inch(35.6 
# ...

# %%
# length of each
print(len(titles),len(ratings),len(l_prices))
# Out:
# 10 10 10

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Title':titles,'Ratings':ratings,'Price':l_prices})
df
# Out:
#                                                Title Ratings     Price
# 0  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....      60    80,990
# 1  Lenovo Ideapad Gaming 3 Intel Core i7 10th Gen...      34    62,990
# 2  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...       8    82,990
# 3  ASUS TUF Dash F15 (2022), 15.6-inch (39.62 cms...       3  1,64,990
# 4  (Renewed) Lenovo Intel Core i7 5600U 12.5-Inch...       8    23,997
# 5  HP Pavilion x360 11th Gen Intel Core i7 14 inc...       4    81,990
# 6  ASUS Zenbook 13 OLED, 13.3-inch (33.78 cms) FH...       6    79,990
# 7  MSI Modern 14, Intel i7-1195G7, 14" FHD IPS-Le...      30    54,990
# 8  ASUS TUF Gaming F15 (2022), 15.6-inch (39.62 c...      89  1,09,990
# 9  Lenovo Yoga 7i 11th Gen Intel Core i7-1165G7 1...      19  1,06,999

# %% [markdown]
# ### Q9: Write a python program to scrape data for first 10 job results for Data Scientist Designation in Noida location. You have to scrape company name, No. of days ago when job was posted, Rating of the company.
#
# This task will be done in following steps:
#
# 1. First get the webpage https://www.ambitionbox.com/
#
# 2. Click on the Job option as shown in the image

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter “Data Scientist” and click on search button.

# %% [markdown]
# ### 4. You will reach to the following web page click on location and in place of “Search location” enter “Noida” and select location “Noida”.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5. Then scrape the data for the first 10 jobs results you get on the above shown page.
#
# 6. Finally create a dataframe of the scraped data.
#
# Note: All the steps required during scraping should be done through code only and not manually

# %%
# step 1- First get the webpage -https://www.ambitionbox.com/
#open the page on automated chrome browser
driver.get('https://www.ambitionbox.com/')

# %%
#/html/body/div/div/div/div[1]/header/nav/ul/li[5]/a

# clicking on job tab

job_tab=driver.find_element(By.XPATH,"/html/body/div/div/div/div[1]/header/nav/ul/li[5]/a")

job_tab.click()

# %%
#entering Data Scientist as required in the question

product_search=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/div/span/input')
product_search.send_keys("Data Scientist")

# %%
#step 3 -After reaching to the next webpage, In place of “Search by Designations, Companies, Skills” enter “Data Scientist” and 
# click on search button.
search=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[1]/div/div/div/button/span')
search.click()

# %%
#You will reach to the following web page click on location and in place of “Search location” enter
#“Noida” and select location “Noida”



location_tab=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[1]/i')
location_tab.click()

# %%
#entering noida

location_input=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[2]/input')
location_input.send_keys("Noida")

# %%
select_location=driver.find_element(By.XPATH,'/html/body/div/div/div/div[2]/div[1]/div[2]/div[1]/div/div/div/div[2]/div[2]/div/div[3]/div[1]/div[1]/div/label')
select_location.click()

# %%
#step 5 -Then scrape the data for the first 10 jobs results you get on the above shown page

positions=[]
company_info=[]
company_ratings=[]
job_infos=[]

#scraping positions from the given page
positions_tags=driver.find_elements(By.XPATH,'//a[@class="title noclick"]')
for i in positions_tags[0:10]:
    pos=i.text
    positions.append(pos)
    
#scraping positions from the given page
company_info_tags=driver.find_elements(By.XPATH,'//div[@class="company-info"]/p')
for i in company_info_tags[0:10]:
    comp_info=i.text
    company_info.append(comp_info)
    
#scraping rating from the given page
company_rating_tags=driver.find_elements(By.XPATH,'//a[@class="rating rating-4"]')
for i in company_rating_tags[0:10]:
    comp_rating=i.text
    company_ratings.append(comp_rating)
    
#scraping job basic info from the given page
job_info_tags=driver.find_elements(By.XPATH,'//div[@class="job-basic-info show-flex"]')
for i in job_info_tags[0:10]:
    job_info=i.text
    job_infos.append(job_info)

company_ratings.append(company_ratings[8])    
skill_info=[]       
experience_req=[]
loc_offered=[]
    
for j in job_infos:
    experience_req.append(j.splitlines()[0])
    skill_info.append(j.splitlines()[2])
    
loc_offered_tags=driver.find_elements(By.XPATH,'//div[@class="entity loc"]')
for i in loc_offered_tags[0:10]:
    loc_off=i.text
    loc_offered.append(loc_off)
    
    

print(positions)
print(company_info)
print(company_ratings)
print(experience_req)
print(loc_offered)

print("skill_info:",len(skill_info))
# Out:
# ['Data Scientist', 'Quality Engineer', 'Data Scientist- SAS Analyst', 'EY GDS - Data Scientist (10-20 yrs)', 'Data Scientist', 'Hiring For Genpact-Data Scientist- Forecasting-Immediate Joiners only', 'Genpact - Data Scientist - Forecasting/Python/R (6-10 yrs)', 'Data Scientist', 'Data Scientist - Machine Learning Algorithms (3-8 yrs)', 'EY - Data Engineer - Data Integration/Modeling (3-8 yrs)']
# [' · ', 'GENPACT India Private Limited', 'Optum Global Solutions (India) Private Limited', 'BARCLAYS GLOBAL SERVICE CENTRE PRIVATE LIMITED', 'EY GDS', 'GLOBALLOGIC INDIA PRIVATE LIMITED', 'GENPACT India Private Limited', 'Genpact', 'Ericsson India Global Services Pvt. Ltd.', 'Dew Solutions Pvt. Ltd.']
# ['4.0', '4.0', '4.1', '4.3', '4.0', '4.0', '4.0', '4.3', '4.3', '4.3']
# ['6-10 years', '6-10 Yrs', '2-7 Yrs', '2-7 Yrs', '10-20 Yrs', '8-10 Yrs', '7-12 Yrs', '6-10 Yrs', '4-12 Yrs', '3-8 Yrs']
# ...

# %%
print(len(positions),len(company_info),len(company_ratings),len(experience_req),len(loc_offered),len(skill_info))
# Out:
# 10 10 10 10 10 10

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Position':positions,'Company':company_info,'Company Rating':company_ratings,'Experienced Required':experience_req,'Locations':loc_offered,'Skill':skill_info})
df
# Out:
#                                             Position  \
# 0                                     Data Scientist
# 1                                   Quality Engineer
# 2                        Data Scientist- SAS Analyst
# 3                EY GDS - Data Scientist (10-20 yrs)
# 4                                     Data Scientist
# 5  Hiring For Genpact-Data Scientist- Forecasting...
# 6  Genpact - Data Scientist - Forecasting/Python/...
# 7                                     Data Scientist
# 8  Data Scientist - Machine Learning Algorithms (...
# 9  EY - Data Engineer - Data Integration/Modeling...
#
#                                           Company Company Rating  \
# 0                                              ·             4.0
# 1                   GENPACT India Private Limited            4.0
# 2  Optum Global Solutions (India) Private Limited            4.1
# 3  BARCLAYS GLOBAL SERVICE CENTRE PRIVATE LIMITED            4.3
# ...

# %% [markdown]
# # Q10: Write a python program to scrape the salary data for Data Scientist designation.You have to scrape Company name, Number of salaries, Average salary, Minsalary, Max Salary.

# %%
#step 1 - 1. First get the webpage https://www.ambitionbox.com/

# step 1- First get the webpage -https://www.ambitionbox.com/
#open the page on automated chrome browser
driver.get('https://www.ambitionbox.com/')

# %%
#Click on the salaries option as shown in the image.

# clicking on salaries tab

sal_tab=driver.find_element(By.XPATH,"/html/body/div/div/div/div[1]/header/nav/ul/li[3]/span")

sal_tab.click()

# %%
# clicking on salaries brows tab

sal_brow_selection=driver.find_element(By.XPATH,"/html/body/div/div/div/div[1]/header/nav/ul/li[3]/div/ul/li[1]/div/div[2]/p")

sal_brow_selection.click()

# %%
#After reaching to the following webpage, In place of “Search Job Profile” enters “Data Scientist” and
#then click on “Data Scientist”.

pos_input=driver.find_element(By.XPATH,'/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/input')
pos_input.send_keys("Data Scientist")

# %%
#hiting by post

pos_hit=driver.find_element(By.XPATH,"/html/body/div/div/div/main/section[1]/div[2]/div[1]/span/div/div/div[1]/div/div/p")

pos_input.click()

# %%
# Scrape the data for the first 10 companies. Scrape the company name, total salary record, average
# salary, minimum salary, maximum salary, experience required.

companies_info=[]
comapny_names=[]
average_salary=[]
minimum_salary=[]
maximum_salary=[]
experience_required=[]

#scraping company info from the given page
company_info_tag=driver.find_elements(By.XPATH,'//div[@class="company-info"]')
for i in company_info_tag[0:10]:
    com_info=i.text
    companies_info.append(com_info)
    
#scraping average CTC from the given page
ctc_info_tag=driver.find_elements(By.XPATH,'//div[@class="average-indicator-wrapper"]/p')
for i in ctc_info_tag[0:10]:
    ctc=i.text
    average_salary.append(ctc)

    
for c in companies_info:
    comapny_names.append(c.splitlines()[0])
    experience_required.append(c.splitlines()[2])

all_sal_info=[]    
    
#scraping all salary range from the given page
sal_info_tag=driver.find_elements(By.XPATH,'//div[@class="salary-range-wrapper"]')
for i in sal_info_tag[0:10]:
    all_sal=i.text
    all_sal_info.append(all_sal)
    
for al in all_sal_info:
    minimum_salary.append(al.splitlines()[1])
    maximum_salary.append(al.splitlines()[2])

print(minimum_salary)
print(maximum_salary)   
print(comapny_names)
print(experience_required)
print(average_salary)
# Out:
# ['₹ 25.0L', '₹ 15.0L', '₹ 11.0L', '₹ 11.0L', '₹ 9.0L', '₹ 9.0L', '₹ 12.7L', '₹ 11.0L', '₹ 12.0L', '₹ 8.8L']
# ['₹ 45.0L', '₹ 26.0L', '₹ 22.6L', '₹ 22.0L', '₹ 23.0L', '₹ 20.0L', '₹ 19.7L', '₹ 20.0L', '₹ 18.0L', '₹ 17.5L']
# ['Walmart', 'Ab Inbev', 'Optum', 'ZS', 'Fractal Analytics', 'Tiger Analytics', 'Sigmoid Analytics', 'Legato Health Technologies', 'HSBC', 'Tredence']
# ['3-4 yrs experience (based on 23 salaries)', '2-4 yrs experience (based on 57 salaries)', '2-4 yrs experience (based on 49 salaries)', '1-2 yrs experience (based on 34 salaries)', '2-4 yrs experience (based on 115 salaries)', '2-4 yrs experience (based on 68 salaries)', '1 yr experience (based on 10 salaries)', '4 yrs experience (based on 11 salaries)', '4 yrs experience (based on 10 salaries)', '3 yrs experience (based on 14 salaries)']
# ['₹ 32.3L', '₹ 19.9L', '₹ 16.4L', '₹ 15.8L', '₹ 15.4L', '₹ 14.7L', '₹ 14.7L', '₹ 14.5L', '₹ 14.0L', '₹ 13.9L']

# %%
print(len(comapny_names),len(experience_required),len(minimum_salary),len(average_salary),len(maximum_salary))
# Out:
# 10 10 10 10 10

# %%
#creating the dataframe from above data-

df=pd.DataFrame({'Company Name':comapny_names,', Average Salary':average_salary,'Minimum Salary':minimum_salary,'Maximum Salary':maximum_salary,'Experience Required':experience_required})
df
# Out:
#                  Company Name , Average Salary Minimum Salary Maximum Salary  \
# 0                     Walmart          ₹ 32.3L        ₹ 25.0L        ₹ 45.0L
# 1                    Ab Inbev          ₹ 19.9L        ₹ 15.0L        ₹ 26.0L
# 2                       Optum          ₹ 16.4L        ₹ 11.0L        ₹ 22.6L
# 3                          ZS          ₹ 15.8L        ₹ 11.0L        ₹ 22.0L
# 4           Fractal Analytics          ₹ 15.4L         ₹ 9.0L        ₹ 23.0L
# 5             Tiger Analytics          ₹ 14.7L         ₹ 9.0L        ₹ 20.0L
# 6           Sigmoid Analytics          ₹ 14.7L        ₹ 12.7L        ₹ 19.7L
# 7  Legato Health Technologies          ₹ 14.5L        ₹ 11.0L        ₹ 20.0L
# 8                        HSBC          ₹ 14.0L        ₹ 12.0L        ₹ 18.0L
# 9                    Tredence          ₹ 13.9L         ₹ 8.8L        ₹ 17.5L
#
#                           Experience Required
# 0   3-4 yrs experience (based on 23 salaries)
# ...
